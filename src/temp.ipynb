# %%
from pathlib import Path
import pandas as pd
import pyarrow

# %%
p = Path.cwd()
data_path = p.parent / "data"
data_path
# Out:
# PosixPath('/Users/jack/Desktop/Fall 2026/CS4120/Final/Fallacy-Detector/data')

# %%
pd.read_parquet(data_path / "train-00000-of-00001-8c3d4e48fe0f561b.parquet")
# Out:
#        config                                     source_article  \
# 0         edu          company's slogan "Expect More. Pay Less."
# 1         edu  The bigger a child's shoe size, the better the...
# 2         edu  Since many people believe this, then it must b...
# 3         edu  Senator Randall isn't lying when she says she ...
# 4         edu  A mother is telling her daughter that she went...
# ...       ...                                                ...
# 2675  climate  As countries get more peaceful in Africa we co...
# 2676  climate  “ It breaks my heart to think we ’ d lose half...
# 2677  climate  Losing tropical forests is not somehow cheaper...
# 2678  climate  Lawrence said a steep drop in emissions to zer...
# 2679  climate  But looking to the future , mass coral bleachi...
#
#           logical_fallacies
# 0         appeal to emotion
# 1           false causality
# 2                ad populum
# 3        circular reasoning
# 4      fallacy of relevance
# ...

# %%
print(pd.__version__)
print(pyarrow.__version__)
# Out:
# 2.2.3
# 17.0.0
