# %%
from pathlib import Path
import pandas as pd
import pyarrow
import json

# %%
p = Path.cwd()
data_path = p.parent.parent / "data"
data_path

# %%
train_data = pd.read_parquet(data_path / "train.parquet")
test_data = pd.read_parquet(data_path / "test.parquet")
dev_data = pd.read_parquet(data_path / "dev.parquet")

# %%
for item in train_data.loc[:5]["source_article"]:
    print(item)

for item in train_data.loc[2600:2605]["source_article"]:
    print(item)

# %%
print(pd.__version__)
print(pyarrow.__version__)
# Out:
# 2.2.3
# 17.0.0

# %%
print(train_data.shape)
print(test_data.shape)
print(dev_data.shape)
# Out:
# (2680, 3)
# (511, 3)
# (570, 3)
